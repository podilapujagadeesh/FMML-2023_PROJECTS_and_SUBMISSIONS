# %% [markdown]
# <a href="https://colab.research.google.com/github/podilapujagadeesh/FMML-2023_PROJECTS_and_SUBMISSIONS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 16:18:40--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   209MB/s    in 0.3s
#
# 2024-03-26 16:18:41 (209 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 40568   1308.4206v2  Motivated by the analysis of nonnegative data ...  stat
# 1260   1709.01686v1  Deep neural networks are state of the art meth...    cs
# 22956  1711.08451v1  The estimation of optimal treatment regimes is...  stat
# 22060   1409.2713v1  Log-linear models are the popular workhorses o...  stat
# 17628  1801.01725v1  It is a challenging and practical research pro...    cs
# ...             ...                                                ...   ...
# 36858  1506.07990v2  Plausibility models are Kripke models that age...    cs
# 7300   1711.08132v1  Convolutional Neural Networks (CNN) and the lo...    cs
# 22104   1411.5271v2  Diffusion-weighted MR imaging (DWI) is the onl...  stat
# 14398  cs/0003060v1  Customer care in technical domains is increasi...    cs
# 6706   1705.07377v1  We extend the classic multi-armed bandit (MAB)...  stat
#
#                                                    title  year  \
# 40568                   Nested Nonnegative Cone Analysis  2013
# 1260   BranchyNet: Fast Inference via Early Exiting f...  2017
# 22956  Causal nearest neighbor rules for optimal trea...  2017
# 22060  Context-specific independence in graphical log...  2014
# 17628  A Multi-task Learning Approach for Improving P...  2018
# ...                                                  ...   ...
# 36858  Bisimulation and expressivity for conditional ...  2015
# 7300                    Locally Smoothed Neural Networks  2017
# 22104  Quantifying error in estimates of human brain ...  2014
# 14398          Message Classification in the Call Center  2000
# 6706                            Instrument-Armed Bandits  2017
#
#                                                 keywords
# 40568  [motivated, nonnegative, nonnegative, drawback...
# 1260   [increasingly, performance, additional, feedfo...
# 22956  [estimation, treatment, considerable, precisio...
# 22060  [workhorses, analyzing, contingency, parameter...
# 17628  [challenging, practical, effective, compressio...
# ...                                                  ...
# 36858  [plausibility, knowledge, themselves, interpre...
# 7300   [convolutional, connected, capturing, importan...
# 22104  [diffusion, currently, connections, different,...
# 14398  [technical, increasingly, communication, repro...
# 6706   [noncompliance, instrument, treatment, instrum...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 40568    [motivated, nonnegative, nonnegative, drawback...
# 1260     [increasingly, performance, additional, feedfo...
# 22956    [estimation, treatment, considerable, precisio...
# 22060    [workhorses, analyzing, contingency, parameter...
# 17628    [challenging, practical, effective, compressio...
#                                ...
# 879      [perspective, introducing, descriptor, framewo...
# 28843    [cognitive, impairment, neurodegenerative, alz...
# 26967    [integrate, algorithm, approaches, hierarchica...
# 22051    [structure, separately, differences, emphdirec...
# 19291    [monotonic, probabilistic, reasoning, monotoni...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8741 words.
# Out of those 4557 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c23a9bd4-e2a2-4199-85df-8bbb8286dda1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c23a9bd4-e2a2-4199-85df-8bbb8286dda1")) {                    Plotly.newPlot(                        "c23a9bd4-e2a2-4199-85df-8bbb8286dda1",                        [{"x":["subspaces","different","usefulness","resulting","factorization","motivated","interpretability","interpretable","naturally","generates","overcomes","simulations","drawbacks","application","determining","illustrate","approximation","nonnegative","structure","components","traditional","sometimes","feedforward","applications","observation","sensitive","significantly","additional","likelihood","performance","difficult","confidence","prediction","inference","frequently","augmented","sufficient","prohibitive","classifiers","increasingly","classification","architecture","increases","simultaneously","eventually","alleviate","dimensionality","depression","neighborhood","theoretical","establish","properties","selection","universally","considerable","framework","estimation","deteriorates","convergence","possesses","simulation","precision","consistent","illustrated","treatment","estimates","identified","parameterization","parameters","development","analyzing","conditional","interpretation","obtaining","projection","restrictions","graphical","contingency","correspond","parameter","restriction","expressive","probabilities","decomposability","independence","arbitrary","neglected","interaction","introduce","independencies","hierarchical","algorithm","mechanism","attentive","summarization","conversion","optimized","demonstrate","important","approaches","improving","optimization","embedding","preprocessing","challenging","particular","practical","annotated","particularly","effective","generating","redundant","distributions","attention","deployment","qualities","compression","extensive","experiments","advantage","extractive","diagnostic","histogram","improvement","synthetic","isotropic","knowledge","computational","classical","statistical","pixelwise","segmentation","difference","complexity","algorithms","segmentations","experimental","anisotropic","available","markovian","environments","hypothesis","automation","distribution","reproducible","following","distinctive","constrained","suboptimal","procedures","influence","considering","multimodal","coefficient","investigate","achievable","challenge","developing","converging","established","developed","significant","exploration","extension","benchmark","comparison","attractive","understand","sequential","approximate","contextual","reinforcement","exploitation","highlight","empirical","posterior","supervised","uncertainty","successful","underlying","providing","understanding","regression","characteristics","strategies","behaviour","frequency","perceived","prevalence","relationship","respectively","microblog","emoticons","arguments","sentiment","clustering","expression","participants","conditions","coefficients"],"y":[21,703,30,142,33,52,17,38,45,29,7,45,16,238,27,68,103,7,349,106,171,28,23,441,59,70,252,127,67,873,158,37,237,195,27,46,56,10,115,46,525,222,45,118,12,22,56,0,27,157,42,191,180,6,34,506,217,2,130,6,94,69,88,20,34,76,42,8,224,116,61,93,47,31,55,12,51,2,26,115,13,24,70,3,25,73,2,82,305,2,118,803,109,12,24,15,57,569,373,452,97,341,111,20,268,270,133,75,77,271,89,18,137,153,21,4,53,173,607,94,3,21,24,123,145,5,364,282,118,137,2,209,61,228,582,16,411,9,307,5,91,61,19,220,5,88,11,74,12,44,76,75,34,26,151,10,160,59,7,40,195,240,54,78,196,135,17,66,70,91,51,99,27,30,157,44,204,58,68,109,91,156,132,78,91,29,61,13,6,65,86,3,4,25,33,157,48,30,135,37],"type":"bar"},{"x":["subspaces","different","usefulness","resulting","factorization","moti ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4557,), (4557, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7983333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Person</span> <span style='background-color:rgba(0, 255, 0, 0.6470588235294117);'>Trajectory</span> <span style='background-color:rgba(0, 255, 0, 0.3053892215568862);'>Representations</span> <span style=''>for</span> <span style=''>Team</span> <span style=''>Activity</span> <span style=''>Analysis</span> <br/><br/><span style=''>Activity</span> <span style=''>analysis</span> <span style=''>in</span> <span style=''>which</span> <span style=''>multiple</span> <span style=''>people</span> <span style=''>interact</span> <span style=''>across</span> <span style=''>a</span> <span style=''>large</span> <span style=''>space</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.4408602150537634);'>challenging</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>interplay</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style=''>actions</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>collective</span> <span style=''>group</span> <span style=''>dynamics</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>person</span> <span style='background-color:rgba(0, 255, 0, 0.6470588235294117);'>trajectory</span> <span style='background-color:rgba(0, 255, 0, 0.3053892215568862);'>representations</span> <span style=''>for</span> <span style=''>group</span> <span style=''>activity</span> <span style=''>analysis</span> <span style=''>The</span> <span style=''>learned</span> <span style='background-color:rgba(0, 255, 0, 0.3053892215568862);'>representations</span> <span style=''>encode</span> <span style=''>rich</span> <span style=''>spatio</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependencies</span> <span style=''>and</span> <span style=''>capture</span> <span style=''>useful</span> <span style=''>motion</span> <span style=''>patterns</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.8421052631578948);'>recognizing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style=''>events</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characteristic</span> <span style=''>group</span> <span style=''>dynamics</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>groups</span> <span style=''>from</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3939393939393939);'>trajectories</span> <span style=''>alone</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>our</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>approach</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>team</span> <span style=''>sports</span> <span style=''>which</span> <span style=''>provide</span> <span style=''>well</span> <span style=''>defined</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>events</span> <span style=''>(eg</span> <span style=''>pass</span> <span style=''>shot)</span> <span style=''>and</span> <span style=''>groups</span> <span style=''>of</span> <span style=''>people</span> <span style=''>(teams)</span> <span style=''>Analysis</span> <span style=''>of</span> <span style=''>events</span> <span style=''>and</span> <span style=''>team</span> <span style='background-color:rgba(0, 255, 0,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Multiple</span> <span style=''>Adaptive</span> <span style=''>Bayesian</span> <span style=''>Linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>for</span> <span style=''>Scalable</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>with</span> <span style=''>Warm</span> <span style=''>Start</span> <br/><br/><span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>(BO)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>model</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>gradient</span> <span style=''>free</span> <span style=''>black</span> <span style=''>box</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Typically</span> <span style=''>BO</span> <span style=''>is</span> <span style=''>powered</span> <span style=''>by</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(GP)</span> <span style=''>whose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithmic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>is</span> <span style=''>cubic</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>Hence</span> <span style=''>GP</span> <span style=''>based</span> <span style=''>BO</span> <span style=''>cannot</span> <span style=''>leverage</span> <span style=''>large</span> <span style=''>amounts</span> <span style=''>of</span> <span style=''>past</span> <span style=''>or</span> <span style=''>related</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>for</span> <span style=''>example</span> <span style=''>to</span> <span style=''>warm</span> <span style=''>start</span> <span style=''>the</span> <span style=''>BO</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>multiple</span> <span style=''>adaptive</span> <span style=''>Bayesian</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>model</span> <span style=''>as</span> <span style=''>a</span> <span style=''>scalable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>whose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>is</span> <span style=''>linear</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>The</span> <span style=''>multiple</span> <span style=''>Bayesian</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>models</span> <span style=''>are</span> <span style=''>coupled</span> <span style=''>through</span> <span style=''>a</span> <span style=''>shared</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>feedforward</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>which</span> <span style=''>learns</span> <span style=''>a</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transfers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>across</span> <span style=''>ma ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Predicting</span> <span style=''>the</span> <span style=''>Likely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Behaviors</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Continuous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Nonlinear</span> <span style=''>Systems</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.47368421052631576);'>Equilibrium</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicting</span> <span style=''>the</span> <span style=''>likely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>behaviors</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonlinear</span> <span style=''>systems</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.47368421052631576);'>equilibrium</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style=''>input</span> <span style=''>values</span> <span style=''>can</span> <span style=''>vary</span> <span style=''>The</span> <span style=''>method</span> <span style=''>uses</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3684210526315789);'>parameterized</span> <span style=''>equation</span> <span style=''>model</span> <span style=''>and</span> <span style=''>a</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style=''>input</span> <span style=''>joint</span> <span style=''>density</span> <span style=''>to</span> <span style=''>bound</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4618473895582329);'>likelihood</span> <span style=''>that</span> <span style=''>some</span> <span style=''>behavior</span> <span style=''>will</span> <span style=''>occur</span> <span style=''>such</span> <span style=''>as</span> <span style=''>a</span> <span style=''>state</span> <span style=''>variable</span> <span style=''>being</span> <span style=''>inside</span> <span style=''>a</span> <span style=''>given</span> <span style=''>numeric</span> <span style=''>range</span> <span style=''>Using</span> <span style=''>a</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style=''>density</span> <span style=''>instead</span> <span style=''>of</span> <span style=''>the</span> <span style=''>density</span> <span style=''>itself</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>desirable</span> <span style=''>because</span> <span style=''>often</span> <span style=''>the</span> <span style=''>input</span> <span style=''>densitys</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>and</span> <span style=''>shape</span> <span style=''>are</span> <span style=''>not</span> <span style=''>exactly</span> <span style=''>known</span> <span style=''>The</span> <span style=''>new</span> <span style=''>method</span> <span style=''>is</span> <span style=''>called</span> <span style=''>SAB</span> <span style=''>after</span> <span style=''>its</span> <span style=''>basic</span> <span style='background-color:rgba(0, 255, 0, 0.3636363636363636);'>operations</span> <span style=''>split</span> <span style=''>the</span> <span style=''>input</span> <span style=''>value</span> <span style=''>space</span> <span style=''>into</span> <span style=''>smaller</span> <span style=''>regions</span> <span style=''>and</span> <span style=''>then</span> <span style=''>bound</span> <span style=''>those</span> <span style=''>regions</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Developments</span> <span style=''>in</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>randomized</span> <span style=''>shortest</span> <span style=''>paths</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>of</span> <span style=''>graph</span> <span style=''>node</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <br/><br/><span style=''>There</span> <span style=''>have</span> <span style=''>lately</span> <span style=''>been</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>suggestions</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>on</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>the</span> <span style=''>shortest</span> <span style=''>path</span> <span style=''>distance</span> <span style=''>and</span> <span style=''>the</span> <span style=''>commute</span> <span style=''>time</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resistance</span> <span style=''>distance</span> <span style=''>The</span> <span style=''>need</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developing</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>has</span> <span style=''>risen</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>that</span> <span style=''>the</span> <span style=''>above</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mentioned</span> <span style=''>common</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>situations</span> <span style=''>fail</span> <span style=''>to</span> <span style=''>take</span> <span style=''>into</span> <span style=''>account</span> <span style=''>the</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>In</span> <span style=''>this</span> <span style=''>article</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>one</span> <span style=''>family</span> <span style=''>of</span> <span style=''>graph</span> <span style=''>node</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>known</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>randomized</span> <span style=''>shortest</span> <span style=''>path</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarity</span> <span style=''>which</span> <span style=''>has</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>foundation</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>physics</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>randomized</span> <span style=''>shortest</span> <span style=''>path</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarity</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily< ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.0948001414927485)
# 	processing (0.10435090201627166)
# 	knowledge (0.12875840113194198)
# 	information (0.24195259992925364)
# 	segmentation (0.07392996108949416)
# 	different (0.248673505482844)
# 	experimental (0.14538379908029714)
# 	detection (0.12345242306331801)
# 	convolutional (0.1273434736469756)
# 	recognition (0.126989741775734)
#
# Some Statistics words are:
# 	algorithms (0.2939685757729346)
# 	variables (0.14445007602635582)
# 	stochastic (0.1429295489102889)
# 	algorithm (0.3928028383172833)
# 	theoretical (0.16472377090724785)
# 	statistical (0.15914850481500253)
# 	dimensional (0.1824632539280284)
# 	distribution (0.1956411556006082)
# 	inference (0.20425747592498733)
# 	regression (0.18297009630005068)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="21b1ff88-593b-4857-b219-f83432b6af6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21b1ff88-593b-4857-b219-f83432b6af6b")) {                    Plotly.newPlot(                        "21b1ff88-593b-4857-b219-f83432b6af6b",                        [{"x":["subspaces","different","usefulness","resulting","factorization","motivated","interpretability","interpretable","naturally","generates","overcomes","simulations","drawbacks","application","determining","illustrate","approximation","nonnegative","structure","components","traditional","sometimes","feedforward","applications","observation","sensitive","significantly","additional","likelihood","performance","difficult","confidence","prediction","inference","frequently","augmented","sufficient","prohibitive","classifiers","increasingly","classification","architecture","increases","simultaneously","eventually","alleviate","dimensionality","depression","neighborhood","theoretical","establish","properties","selection","universally","considerable","framework","estimation","deteriorates","convergence","possesses","simulation","precision","consistent","illustrated","treatment","estimates","identified","parameterization","parameters","development","analyzing","conditional","interpretation","obtaining","projection","restrictions","graphical","contingency","correspond","parameter","restriction","expressive","probabilities","decomposability","independence","arbitrary","neglected","interaction","introduce","independencies","hierarchical","algorithm","mechanism","attentive","summarization","conversion","optimized","demonstrate","important","approaches","improving","optimization","embedding","preprocessing","challenging","particular","practical","annotated","particularly","effective","generating","redundant","distributions","attention","deployment","qualities","compression","extensive","experiments","advantage","extractive","diagnostic","histogram","improvement","synthetic","isotropic","knowledge","computational","classical","statistical","pixelwise","segmentation","difference","complexity","algorithms","segmentations","experimental","anisotropic","available","markovian","environments","hypothesis","automation","distribution","reproducible","following","distinctive","constrained","suboptimal","procedures","influence","considering","multimodal","coefficient","investigate","achievable","challenge","developing","converging","established","developed","significant","exploration","extension","benchmark","comparison","attractive","understand","sequential","approximate","contextual","reinforcement","exploitation","highlight","empirical","posterior","supervised","uncertainty","successful","underlying","providing","understanding","regression","characteristics","strategies","behaviour","frequency","perceived","prevalence","relationship","respectively","microblog","emoticons","arguments","sentiment","clustering","expression","participants","conditions","coefficients","polynomial","sensitivity","relevance","technique","performances","metamodel","predictions","modelling","calculated","calculate","convolutional","projective","optimizing","operations","quantities","convolution","receptive","deconvolutional","propositions","referring","literature","fundamentally","translated","reasoning","proposition","representation","formalize","apparently","respective","autoepistemic","attempted","intuitions","perspective","formalization","nonmonotonic","discoveries","computers","extraction","accomplished","increased","alongside","procedure","activities","probability","transform","employing","contributes","hierarchy","dimensions","alternative","validation","locations","discriminating","problematic","univariate","esp ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	depression
# 	geostatistical
# 	covariates
# 	injecting
# 	couplings
# 	interdependence
# 	correntropy
# 	staleness
# 	poisoning
# 	detectability
# 	regularizations
# 	prespecified
# 	popularized
# 	privately
# 	straggler
# 	electroencephalography
# 	resiliency
# 	consonants
# 	scrambled
# 	unanswered
# Some words which never appear in Statistics papers:
# 	extractive
# 	microblog
# 	propositions
# 	proposition
# 	apparently
# 	autoepistemic
# 	nonmonotonic
# 	microblogs
# 	homophily
# 	disambiguating
# 	hyperedges
# 	degenerated
# 	instagram
# 	sarcastic
# 	concatenates
# 	pathological
# 	disjunctive
# 	propositional
# 	mismatches
# 	concomitant

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.04627288512505e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7391666666666666
